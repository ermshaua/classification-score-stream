# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../../")

from tqdm import tqdm

# %%
from src.visualizer import plot_profile, plot_profile_with_ts

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ClaSS", "FLOSS", "DDM", "Window", "BOCD", "ADWIN", "HDDM"]
datasets = ["UTSA", "TSSB"] # 
methods, dfs = list(), list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))


for idx, (name, file_name) in enumerate(methods):
    df = pd.concat([pd.read_csv(f"../../experiments/competitor_{d}/{file_name}", usecols=["dataset", eval_score]) for d in datasets])
    df.sort_values(by="dataset", inplace=True)
    dfs.append((name, df))
        
df_scores = pd.DataFrame()

for name, df in dfs:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]
    
df_scores.reset_index(drop=True, inplace=True)
df_scores
# Out:
#                                               dataset  ClaSS  FLOSS    DDM  \
# 0                                               Adiac  0.706  0.445  0.415
# 1                                           ArrowHead  0.985  0.500  0.753
# 2                                                Beef  0.939  0.500  0.538
# 3                                           BeetleFly  0.682  0.500  0.668
# 4                                         BirdChicken  0.977  0.500  0.444
# 5                                                 CBF  0.969  0.949  0.530
# 6                                                Cane  0.831  0.637  0.858
# 7                                                 Car  0.889  0.256  0.610
# 8                                           Chinatown  1.000  1.000  0.588
# 9                               ChlorineConcentration  0.577  0.577  0.614
# 10                                       CinCECGTorso  0.337  0.337  0.413
# 11                                             Coffee  0.996  0.500  0.472
# 12                                          Computers  0.500  0.500  0.460
# 13                                           CricketX  0.954  0.203  0.359
# 14                                           CricketY  0.982  0.202  0.371
# 15                                           CricketZ  0.905  0.202  0.272
# 16                                               Crop  0.958  0.359  0.292
# 17                                DiatomSizeReduction  0.949  0.342  0.733
# 18                       DistalPhalanxOutlineAgeGroup  0.983  0.569  0.910
# 19                                    DistalPhalanxTW  0.769  0.474  0.378
# 20                                      DodgerLoopDay  1.000  1.000  0.741
# 21                                       DutchFactory  0.998  0.973  0.626
# 22                                             ECG200  0.988  0.572  0.813
# 23                                        ECGFiveDays  0.524  0.524  0.504
# 24                                             EEGRat  0.885  0.500  0.582
# 25                                            EEGRat2  0.739  0.500  0.646
# 26                                EOGHorizontalSignal  0.608  0.256  0.553
# 27                                  EOGVerticalSignal  0.728  0.170  0.357
# 28                                            FaceAll  0.864  0.513  0.265
# 29                                           FaceFour  0.741  0.281  0.479
# 30                                           FacesUCR  0.930  0.414  0.229
# 31                                          Fetal2013  0.781  0.553  0.395
# 32                                         FiftyWords  0.960  0.278  0.458
# 33                                               Fish  0.983  0.144  0.182
# 34                                FreezerRegularTrain  0.882  0.260  0.508
# 35                                   GrandMalSeizures  0.542  0.587  0.439
# 36                                  GrandMalSeizures2  0.761  0.508  0.666
# 37                                       GreatBarbet1  0.877  0.531  0.641
# 38                                       GreatBarbet2  0.817  0.792  0.991
# 39                                           GunPoint  0.864  0.501  0.666
# 40                                                Ham  0.641  0.251  0.550
# 41                                            Haptics  0.600  0.356  0.485
# 42                                            Herring  1.000  1.000  0.806
# 43                                        InlineSkate  0.358  0.358  0.476
# 44                                         InsectEPG1  0.751  0.255  0.653
# 45                                         InsectEPG2  0.981  0.925  0.764
# 46                                         InsectEPG3  0.997  0.894  0.600
# 47                                         InsectEPG4  0.987  0.537  0.723
# 48                                InsectWingbeatSound  0.915  0.686  0.402
# 49                                   ItalyPowerDemand  0.996  0.938  0.909
# 50                             LargeKitchenAppliances  0.333  0.333  0.752
# 51                                         Lightning2  0.556  0.556  0.853
# 52                                         Lightning7  0.798  0.215  0.447
# 53                                             Mallat  0.921  0.267  0.586
# 54                                               Meat  0.618  0.487  0.429
# 55                                      MedicalImages  0.580  0.580  0.348
# 56                                MelbournePedestrian  0.943  0.356  0.369
# 57                       MiddlePhalanxOutlineAgeGroup  0.802  0.249  0.387
# 58                        MiddlePhalanxOutlineCorrect  0.827  0.616  0.461
# 59                                    MiddlePhalanxTW  1.000  1.000  0.410
# 60                                         MoteStrain  0.897  0.500  0.511
# 61                                           NogunGun  0.802  0.823  0.518
# 62                         NonInvasiveFetalECGThorax1  0.791  0.555  0.207
# 63                         NonInvasiveFetalECGThorax2  0.991  0.513  0.145
# 64                                            OSULeaf  0.747  0.365  0.351
# 65                                           OliveOil  0.934  0.732  0.453
# 66           PigInternalBleedingDatasetAirwayPressure  0.483  0.500  0.500
# 67   PigInternalBleedingDatasetArtPressureFluidFilled  0.995  0.987  0.500
# 68                      PigInternalBleedingDatasetCVP  0.986  0.929  0.500
# 69                                              Plane  0.927  0.377  0.243
# 70                                        Powerdemand  0.335  0.278  0.515
# 71                     ProximalPhalanxOutlineAgeGroup  0.883  0.445  0.399
# 72                      ProximalPhalanxOutlineCorrect  0.559  0.530  0.682
# 73                                  ProximalPhalanxTW  0.971  0.497  0.633
# 74                                PulsusParadoxusECG1  1.000  0.510  0.444
# 75                                PulsusParadoxusECG2  0.824  0.676  0.567
# 76                                PulsusParadoxusSP02  0.665  0.808  0.495
# 77                                RoboticDogActivityX  0.996  0.666  0.542
# 78                                RoboticDogActivityY  0.997  0.711  0.477
# 79                                RoboticDogActivityZ  0.656  0.716  0.539
# 80                                        ShapeletSim  1.000  1.000  0.458
# 81                                          ShapesAll  0.962  0.740  0.732
# 82                                    SimpleSynthetic  0.995  0.344  0.498
# 83                              SonyAIBORobotSurface1  0.580  0.580  0.874
# 84                              SonyAIBORobotSurface2  0.972  0.517  0.515
# 85                                         Strawberry  0.332  0.332  0.399
# 86                                SuddenCardiacDeath1  0.683  0.465  0.415
# 87                                SuddenCardiacDeath2  0.992  0.475  0.605
# 88                                SuddenCardiacDeath3  0.942  0.484  0.605
# 89                                        SwedishLeaf  0.887  0.400  0.623
# 90                                            Symbols  0.518  0.297  0.802
# 91                                   SyntheticControl  0.978  0.362  0.450
# 92                                            TiltABP  0.445  0.288  0.531
# 93                                            TiltECG  0.916  0.487  0.531
# 94                                   ToeSegmentation1  0.761  0.500  0.638
# 95                                   ToeSegmentation2  0.891  0.500  0.752
# 96                                              Trace  0.652  0.644  0.344
# 97                                         TwoLeadECG  0.501  0.501  0.739
# 98                                                UMD  1.000  1.000  0.553
# 99                             UWaveGestureLibraryAll  0.994  0.201  0.499
# 100                              UWaveGestureLibraryX  0.985  0.201  0.499
# 101                              UWaveGestureLibraryY  0.774  0.201  0.697
# 102                              UWaveGestureLibraryZ  0.779  0.402  0.565
# 70    0.023  0.515  0.269  0.006
# 71    0.376  0.337  0.376  0.376
# 72    0.292  0.601  0.292  0.292
# 73    0.395  0.457  0.395  0.395
# 74    0.510  0.510  0.466  0.930
# 75    0.510  0.510  0.510  0.510
# 76    0.510  0.510  0.447  0.622
# 77    0.882  0.412  0.568  0.568
# 78    0.897  0.374  0.604  0.604
# 79    0.537  0.418  0.543  0.537
# 80    1.000  0.669  1.000  1.000
# 81    0.200  0.200  0.388  0.395
# 82    0.344  0.344  0.240  0.678
# 83    0.580  0.776  0.580  0.580
# 84    0.718  0.601  0.517  0.517
# 85    0.332  0.466  0.332  0.332
# 86    0.034  0.415  0.604  0.009
# 87    0.024  0.605  0.272  0.008
# 88    0.024  0.605  0.341  0.004
# 89    0.460  0.415  0.252  0.252
# 90    0.334  0.297  0.301  0.281
# 91    0.760  0.275  0.200  0.200
# 92    0.054  0.531  0.073  0.006
# 93    0.074  0.531  0.474  0.002
# 94    0.840  0.730  0.476  0.500
# 95    0.500  0.500  0.634  0.500
# 96    0.344  0.344  0.429  0.344
# 97    0.501  0.479  0.501  0.501
# 98    0.859  1.000  0.071  0.244
# 99    0.377  0.351  0.201  0.201
# 100   0.373  0.366  0.201  0.201
# 101   0.381  0.393  0.201  0.201
# 102   0.589  0.368  0.201  0.201
# 103   0.715  0.337  0.322  0.043
# 104   0.337  0.337  0.383  0.084
# 105   0.820  0.788  0.832  0.727
# 106   0.504  0.502  0.504  0.504

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_778/2219294936.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_scores.mean(axis=0).round(3)
# ClaSS     0.812
# FLOSS     0.521
# DDM       0.535
# Window    0.461
# BOCD      0.481
# ADWIN     0.383
# HDDM      0.365
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_778/1729043111.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_scores.median(axis=0).round(3)
# ClaSS     0.882
# FLOSS     0.500
# DDM       0.513
# Window    0.474
# BOCD      0.494
# ADWIN     0.342
# HDDM      0.333
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_778/1084607075.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_scores.std(axis=0).round(3)
# ClaSS     0.190
# FLOSS     0.227
# DDM       0.169
# Window    0.247
# BOCD      0.190
# ADWIN     0.206
# HDDM      0.248
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_778/3065857076.py:1: FutureWarning: Dropping of nuisance columns in DataFrame.rank is deprecated; in a future version this will raise TypeError. Select only valid columns before calling rank.
#   ranks = df_scores.rank(1, method = 'min', ascending=False)

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# ClaSS:wins=81 rank=1.4
# FLOSS:wins=13 rank=3.2
# DDM:wins=11 rank=3.4
# Window:wins=12 rank=3.5
# BOCD:wins=9 rank=3.7
# ADWIN:wins=5 rank=4.4
# HDDM:wins=5 rank=4.5

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4, filename=f"../../figures/cd_comparative_benchmark.pdf") #

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue
    
    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=False)
    
    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs FLOSS: (wins/ties/losses): 83/17/7
# ClaSS vs DDM: (wins/ties/losses): 91/0/16
# ClaSS vs Window: (wins/ties/losses): 87/12/8
# ClaSS vs BOCD: (wins/ties/losses): 90/7/10
# ClaSS vs ADWIN: (wins/ties/losses): 92/12/3
# ClaSS vs HDDM: (wins/ties/losses): 92/15/0

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10,5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)
    
ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0+.2,.2),1))
    
plt.savefig(f"../../figures/bp_comparative_benchmark.pdf", bbox_inches="tight")
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_778/2617034252.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_778/2617034252.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
