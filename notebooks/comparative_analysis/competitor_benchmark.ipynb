# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../../")

from tqdm import tqdm

# %%
from src.profile_visualization import plot_profile, plot_profile_with_ts

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["NEWMA", "HDDM", "ADWIN", "BOCD", "DDM", "Window", "FLOSS", "ChangeFinder", "ClaSS"] #  "MMDEW"
datasets = ["UTSA", "TSSB"] # 
methods, dfs = list(), list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))


for idx, (name, file_name) in enumerate(methods):
    df = pd.concat([pd.read_csv(f"../../experiments/competitor_{d}/{file_name}", usecols=["dataset", eval_score]) for d in datasets])
    df.sort_values(by="dataset", inplace=True)
    dfs.append((name, df))
        
df_scores = pd.DataFrame()

for name, df in dfs:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]
    
rec_seg = [
    "Crop",
    "EOGHorizontalSignal",
    "EOGVerticalSignal",
    "FreezerRegularTrain",
    "Ham",
    "MelbournePedestrian",
    "MiddlePhalanxOutlineAgeGroup",
    "MiddlePhalanxOutlineCorrect",
    "ProximalPhalanxOutlineCorrect",
    "Strawberry"
]

df_scores.reset_index(drop=True, inplace=True)
df_scores
# Out:
#                                               dataset  NEWMA   HDDM  ADWIN  \
# 0                                               Adiac  0.303  0.303  0.303
# 1                                           ArrowHead  0.500  0.500  0.653
# 2                                                Beef  0.500  0.500  0.331
# 3                                           BeetleFly  0.500  0.500  0.901
# 4                                         BirdChicken  0.500  0.500  0.470
# 5                                                 CBF  0.342  0.342  0.342
# 6                                                Cane  0.507  0.630  0.312
# 7                                                 Car  0.256  0.256  0.256
# 8                                           Chinatown  1.000  1.000  1.000
# 9                               ChlorineConcentration  0.577  0.577  0.577
# 10                                       CinCECGTorso  0.337  0.317  0.509
# 11                                             Coffee  0.500  0.500  0.639
# 12                                          Computers  0.500  0.500  0.500
# 13                                           CricketX  0.203  0.203  0.203
# 14                                           CricketY  0.202  0.202  0.202
# 15                                           CricketZ  0.202  0.202  0.202
# 16                                               Crop  0.125  0.125  0.125
# 17                                DiatomSizeReduction  0.342  0.342  0.342
# 18                       DistalPhalanxOutlineAgeGroup  0.668  0.668  0.668
# 19                                    DistalPhalanxTW  0.474  0.474  0.474
# 20                                      DodgerLoopDay  1.000  0.097  0.046
# 21                                       DutchFactory  0.626  0.005  0.281
# 22                                             ECG200  0.572  0.572  0.572
# 23                                        ECGFiveDays  0.524  0.524  0.524
# 24                                             EEGRat  0.500  0.500  0.616
# 25                                            EEGRat2  0.500  0.500  0.500
# 26                                EOGHorizontalSignal  0.256  0.256  0.472
# 27                                  EOGVerticalSignal  0.170  0.170  0.433
# 28                                            FaceAll  0.143  0.143  0.143
# 29                                           FaceFour  0.281  0.487  0.539
# 30                                           FacesUCR  0.152  0.152  0.152
# 31                                          Fetal2013  0.333  0.006  0.183
# 32                                         FiftyWords  0.278  0.278  0.278
# 33                                               Fish  0.144  0.144  0.144
# 34                                FreezerRegularTrain  0.260  0.260  0.369
# 35                                   GrandMalSeizures  0.506  0.007  0.495
# 36                                  GrandMalSeizures2  0.508  0.008  0.508
# 37                                       GreatBarbet1  0.355  0.674  0.438
# 38                                       GreatBarbet2  0.355  0.696  0.469
# 39                                           GunPoint  0.501  0.501  0.500
# 40                                                Ham  0.251  0.251  0.308
# 41                                            Haptics  0.356  0.356  0.464
# 42                                            Herring  1.000  1.000  0.904
# 43                                        InlineSkate  0.358  0.220  0.243
# 44                                         InsectEPG1  0.653  0.653  0.439
# 45                                         InsectEPG2  0.705  0.705  0.294
# 46                                         InsectEPG3  0.631  0.631  0.721
# 47                                         InsectEPG4  0.723  0.723  0.192
# 48                                InsectWingbeatSound  0.250  0.250  0.250
# 49                                   ItalyPowerDemand  0.500  0.500  0.500
# 50                             LargeKitchenAppliances  0.333  0.333  0.333
# 51                                         Lightning2  0.556  0.556  0.556
# 52                                         Lightning7  0.215  0.304  0.297
# 53                                             Mallat  0.267  0.267  0.294
# 54                                               Meat  0.333  0.333  0.333
# 55                                      MedicalImages  0.580  0.580  0.580
# 56                                MelbournePedestrian  0.149  0.149  0.149
# 57                       MiddlePhalanxOutlineAgeGroup  0.250  0.250  0.274
# 58                        MiddlePhalanxOutlineCorrect  0.334  0.334  0.334
# 59                                    MiddlePhalanxTW  1.000  1.000  0.314
# 60                                         MoteStrain  0.500  0.500  0.502
# 61                                           NogunGun  0.518  0.036  0.026
# 62                         NonInvasiveFetalECGThorax1  0.169  0.169  0.169
# 63                         NonInvasiveFetalECGThorax2  0.145  0.145  0.145
# 64                                            OSULeaf  0.365  0.365  0.365
# 65                                           OliveOil  0.382  0.116  0.086
# 66           PigInternalBleedingDatasetAirwayPressure  0.500  0.110  0.056
# 67   PigInternalBleedingDatasetArtPressureFluidFilled  0.500  0.018  0.013
# 68                      PigInternalBleedingDatasetCVP  0.500  0.066  0.049
# 69                                              Plane  0.150  0.150  0.150
# 70                                        Powerdemand  0.515  0.006  0.269
# 71                     ProximalPhalanxOutlineAgeGroup  0.376  0.376  0.376
# 72                      ProximalPhalanxOutlineCorrect  0.292  0.292  0.292
# 73                                  ProximalPhalanxTW  0.395  0.395  0.395
# 74                                PulsusParadoxusECG1  0.510  0.930  0.466
# 75                                PulsusParadoxusECG2  0.510  0.510  0.510
# 76                                PulsusParadoxusSP02  0.510  0.622  0.447
# 77                                RoboticDogActivityX  0.568  0.568  0.568
# 78                                RoboticDogActivityY  0.604  0.604  0.604
# 79                                RoboticDogActivityZ  0.537  0.537  0.543
# 80                                        ShapeletSim  1.000  1.000  1.000
# 81                                          ShapesAll  0.200  0.395  0.388
# 82                                    SimpleSynthetic  0.344  0.678  0.240
# 83                              SonyAIBORobotSurface1  0.580  0.580  0.580
# 84                              SonyAIBORobotSurface2  0.517  0.517  0.517
# 85                                         Strawberry  0.332  0.332  0.332
# 86                                SuddenCardiacDeath1  0.415  0.009  0.604
# 87                                SuddenCardiacDeath2  0.605  0.008  0.272
# 88                                SuddenCardiacDeath3  0.605  0.004  0.341
# 89                                        SwedishLeaf  0.252  0.252  0.252
# 90                                            Symbols  0.297  0.281  0.301
# 91                                   SyntheticControl  0.200  0.200  0.200
# 92                                            TiltABP  0.531  0.006  0.073
# 93                                            TiltECG  0.531  0.002  0.474
# 94                                   ToeSegmentation1  0.500  0.500  0.476
# 95                                   ToeSegmentation2  0.500  0.500  0.634
# 96                                              Trace  0.344  0.344  0.429
# 97                                         TwoLeadECG  0.501  0.501  0.501
# 98                                                UMD  1.000  0.244  0.071
# 99                             UWaveGestureLibraryAll  0.201  0.201  0.201
# 100                              UWaveGestureLibraryX  0.201  0.201  0.201
# 101                              UWaveGestureLibraryY  0.201  0.201  0.201
# 102                              UWaveGestureLibraryZ  0.201  0.201  0.201
# 103                                       WalkJogRun1  0.337  0.043  0.322
# 104                                       WalkJogRun2  0.337  0.084  0.383
# 105                                      WordSynonyms  0.727  0.727  0.832
# 106                                              Yoga  0.504  0.504  0.504
#
#       BOCD    DDM  Window  FLOSS  ChangeFinder  ClaSS
# 0    0.433  0.415   0.303  0.445         0.303  0.706
# 1    0.500  0.753   0.500  0.500         0.500  0.985
# 2    0.500  0.538   0.500  0.500         0.500  0.939
# 3    0.476  0.668   0.500  0.500         0.903  0.682
# 4    0.500  0.444   0.500  0.500         0.849  0.977
# 5    0.503  0.530   0.342  0.949         0.342  0.969
# 6    0.503  0.858   0.507  0.637         0.507  0.831
# 7    0.543  0.610   0.256  0.256         0.256  0.889
# 8    0.688  0.588   1.000  1.000         0.996  1.000
# 9    0.589  0.614   0.577  0.577         0.578  0.577
# 10   0.337  0.413   0.583  0.337         0.351  0.337
# 11   0.506  0.472   0.500  0.500         0.500  0.996
# 12   0.698  0.460   0.819  0.500         0.788  0.500
# 13   0.338  0.359   0.473  0.203         0.203  0.954
# 14   0.359  0.371   0.603  0.202         0.202  0.982
# 15   0.351  0.272   0.387  0.202         0.202  0.905
# 16   0.329  0.292   0.433  0.359         0.125  0.958
# 17   0.342  0.733   0.342  0.342         0.342  0.949
# 18   0.668  0.910   0.668  0.569         0.669  0.983
# 19   0.378  0.378   0.474  0.474         0.474  0.769
# 20   1.000  0.741   1.000  1.000         1.000  1.000
# 21   0.626  0.626   0.033  0.973         0.626  0.998
# 22   0.763  0.813   0.572  0.572         0.572  0.988
# 23   0.581  0.504   0.857  0.524         0.523  0.524
# 24   0.851  0.582   0.616  0.500         0.500  0.885
# 25   0.516  0.646   0.856  0.500         0.500  0.739
# 26   0.256  0.553   0.256  0.256         0.256  0.608
# 27   0.170  0.357   0.170  0.170         0.170  0.728
# 28   0.235  0.265   0.491  0.513         0.143  0.864
# 29   0.483  0.479   0.281  0.281         0.481  0.741
# 30   0.235  0.229   0.595  0.414         0.152  0.930
# 31   0.333  0.395   0.064  0.553         0.333  0.781
# 32   0.266  0.458   0.427  0.278         0.278  0.960
# 33   0.144  0.182   0.144  0.144         0.144  0.983
# 34   0.260  0.508   0.260  0.260         0.260  0.882
# 35   0.506  0.439   0.007  0.587         0.506  0.542
# 36   0.508  0.666   0.013  0.508         0.508  0.761
# 37   0.592  0.641   0.355  0.531         0.355  0.877
# 38   0.729  0.991   0.355  0.792         0.355  0.817
# 39   0.501  0.666   0.501  0.501         0.501  0.864
# 40   0.249  0.550   0.333  0.251         0.251  0.641
# 41   0.356  0.485   0.356  0.356         0.708  0.600
# 42   1.000  0.806   1.000  1.000         1.000  1.000
# 43   0.358  0.476   0.732  0.358         0.615  0.358
# 44   0.657  0.653   0.653  0.255         0.653  0.751
# 45   0.715  0.764   0.705  0.925         0.705  0.981
# 46   0.641  0.600   0.631  0.894         0.631  0.997
# 47   0.728  0.723   0.723  0.537         0.630  0.987
# 48   0.468  0.402   0.745  0.686         0.250  0.915
# 49   0.562  0.909   0.500  0.938         0.500  0.996
# 50   0.330  0.752   0.333  0.333         0.333  0.333
# 51   0.921  0.853   0.556  0.556         0.556  0.556
# 52   0.448  0.447   0.292  0.215         0.215  0.798
# 53   0.267  0.586   0.267  0.267         0.267  0.921
# 54   0.333  0.429   0.333  0.487         0.333  0.618
# 55   0.580  0.348   0.236  0.580         0.580  0.580
# 56   0.333  0.369   0.403  0.356         0.149  0.943
# 57   0.250  0.387   0.250  0.249         0.501  0.802
# 58   0.505  0.461   0.334  0.616         0.334  0.827
# 59   1.000  0.410   1.000  1.000         1.000  1.000
# 60   0.500  0.511   0.500  0.500         0.500  0.897
# 61   0.518  0.518   0.458  0.823         0.661  0.802
# 62   0.169  0.207   0.169  0.555         0.169  0.791
# 63   0.146  0.145   0.145  0.513         0.145  0.991
# 64   0.494  0.351   0.547  0.365         0.365  0.747
# 65   0.382  0.453   0.382  0.732         0.382  0.934
# 66   0.223  0.500   0.500  0.500         0.245  0.483
# 67   0.500  0.500   0.500  0.987         1.000  0.995
# 68   0.594  0.500   0.500  0.929         0.920  0.986
# 69   0.285  0.243   0.150  0.377         0.150  0.927
# 70   0.515  0.515   0.023  0.278         0.723  0.335
# 71   0.337  0.399   0.376  0.445         0.376  0.883
# 72   0.601  0.682   0.292  0.530         0.292  0.559
# 73   0.457  0.633   0.395  0.497         0.395  0.971
# 74   0.510  0.444   0.510  0.510         0.510  1.000
# 75   0.510  0.567   0.510  0.676         0.510  0.824
# 76   0.510  0.495   0.510  0.808         0.510  0.665
# 77   0.412  0.542   0.882  0.666         0.568  0.996
# 78   0.374  0.477   0.897  0.711         0.604  0.997
# 79   0.418  0.539   0.537  0.716         0.537  0.656
# 80   0.669  0.458   1.000  1.000         1.000  1.000
# 81   0.200  0.732   0.200  0.740         0.514  0.962
# 82   0.344  0.498   0.344  0.344         0.999  0.995
# 83   0.776  0.874   0.580  0.580         0.580  0.580
# 84   0.601  0.515   0.718  0.517         0.517  0.972
# 85   0.466  0.399   0.332  0.332         0.332  0.332
# 86   0.415  0.415   0.034  0.465         0.415  0.683
# 87   0.605  0.605   0.024  0.475         0.642  0.992
# 88   0.605  0.605   0.024  0.484         0.605  0.942
# 89   0.415  0.623   0.460  0.400         0.252  0.887
# 90   0.297  0.802   0.334  0.297         0.296  0.518
# 91   0.275  0.450   0.760  0.362         0.200  0.978
# 92   0.531  0.531   0.054  0.288         0.531  0.445
# 93   0.531  0.531   0.074  0.487         0.531  0.916
# 94   0.730  0.638   0.840  0.500         0.500  0.761
# 95   0.500  0.752   0.500  0.500         0.500  0.891
# 96   0.344  0.344   0.344  0.644         0.344  0.652
# 97   0.479  0.739   0.501  0.501         0.500  0.501
# 98   1.000  0.553   0.859  1.000         0.999  1.000
# 99   0.351  0.499   0.377  0.201         0.201  0.994
# 100  0.366  0.499   0.373  0.201         0.201  0.985
# 101  0.393  0.697   0.381  0.201         0.201  0.774
# 102  0.368  0.565   0.589  0.402         0.201  0.779
# 103  0.337  0.315   0.715  0.412         0.337  0.864
# 104  0.337  0.330   0.337  0.657         0.335  0.830
# 105  0.788  0.709   0.820  0.805         0.727  0.727
# 106  0.502  0.513   0.504  0.561         0.669  0.504

# %%
from src.utils import load_benchmark_dataset
df_data = load_benchmark_dataset()
df_scores[df_data.change_points.apply(len) > 1].shape
# Out:
# (55, 10)

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2324/2219294936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0).round(3)
# NEWMA           0.434
# HDDM            0.365
# ADWIN           0.383
# BOCD            0.481
# DDM             0.535
# Window          0.461
# FLOSS           0.521
# ChangeFinder    0.473
# ClaSS           0.812
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2324/1729043111.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.median(axis=0).round(3)
# NEWMA           0.474
# HDDM            0.333
# ADWIN           0.342
# BOCD            0.494
# DDM             0.513
# Window          0.474
# FLOSS           0.500
# ChangeFinder    0.500
# ClaSS           0.882
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2324/1084607075.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0).round(3)
# NEWMA           0.206
# HDDM            0.248
# ADWIN           0.206
# BOCD            0.190
# DDM             0.169
# Window          0.247
# FLOSS           0.227
# ChangeFinder    0.235
# ClaSS           0.190
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# NEWMA:wins=9 rank=4.1
# HDDM:wins=5 rank=5.0
# ADWIN:wins=4 rank=5.1
# BOCD:wins=8 rank=4.1
# DDM:wins=10 rank=4.0
# Window:wins=12 rank=3.9
# FLOSS:wins=12 rank=3.5
# ChangeFinder:wins=12 rank=4.0
# ClaSS:wins=78 rank=1.5

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4, filename=f"../../figures/cd_comparative_benchmark.pdf") #

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue
    
    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=False)
    
    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs NEWMA: (wins/ties/losses): 85/19/3
# ClaSS vs HDDM: (wins/ties/losses): 92/15/0
# ClaSS vs ADWIN: (wins/ties/losses): 92/12/3
# ClaSS vs BOCD: (wins/ties/losses): 90/7/10
# ClaSS vs DDM: (wins/ties/losses): 91/0/16
# ClaSS vs Window: (wins/ties/losses): 87/12/8
# ClaSS vs FLOSS: (wins/ties/losses): 83/17/7
# ClaSS vs ChangeFinder: (wins/ties/losses): 86/10/11

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10,5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)
    
ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0+.2,.2),1))
    
plt.savefig(f"../../figures/bp_comparative_benchmark.pdf", bbox_inches="tight")
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2324/2617034252.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2324/2617034252.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
