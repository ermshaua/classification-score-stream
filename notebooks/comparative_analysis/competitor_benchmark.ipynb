# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../../")

from tqdm import tqdm

# %%
from src.visualizer import plot_profile, plot_profile_with_ts

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ClaSS", "FLOSS", "BOCD", "Window"]
datasets = ["UTSA", "TSSB"] # 
methods, dfs = list(), list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))


for idx, (name, file_name) in enumerate(methods):
    df = pd.concat([pd.read_csv(f"../../experiments/competitor_{d}/{file_name}", usecols=["dataset", eval_score]) for d in datasets])
    df.sort_values(by="dataset", inplace=True)
    dfs.append((name, df))
        
df_scores = pd.DataFrame()

for name, df in dfs:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]
    
df_scores.reset_index(drop=True, inplace=True)
df_scores
# Out:
#                                               dataset  ClaSS  FLOSS   BOCD  \
# 0                                               Adiac  0.706  0.445  0.433
# 1                                           ArrowHead  0.985  0.500  0.500
# 2                                                Beef  0.939  0.500  0.500
# 3                                           BeetleFly  0.682  0.500  0.476
# 4                                         BirdChicken  0.977  0.500  0.500
# 5                                                 CBF  0.969  0.949  0.503
# 6                                                Cane  0.831  0.637  0.503
# 7                                                 Car  0.889  0.256  0.543
# 8                                           Chinatown  1.000  1.000  0.688
# 9                               ChlorineConcentration  0.577  0.577  0.589
# 10                                       CinCECGTorso  0.337  0.337  0.337
# 11                                             Coffee  0.996  0.500  0.506
# 12                                          Computers  0.500  0.500  0.698
# 13                                           CricketX  0.954  0.203  0.338
# 14                                           CricketY  0.982  0.202  0.359
# 15                                           CricketZ  0.905  0.202  0.351
# 16                                               Crop  0.958  0.359  0.329
# 17                                DiatomSizeReduction  0.949  0.342  0.342
# 18                       DistalPhalanxOutlineAgeGroup  0.983  0.569  0.668
# 19                                    DistalPhalanxTW  0.769  0.474  0.378
# 20                                      DodgerLoopDay  1.000  1.000  1.000
# 21                                       DutchFactory  0.998  0.973  0.626
# 22                                             ECG200  0.988  0.572  0.763
# 23                                        ECGFiveDays  0.524  0.524  0.581
# 24                                             EEGRat  0.885  0.500  0.851
# 25                                            EEGRat2  0.739  0.500  0.516
# 26                                EOGHorizontalSignal  0.608  0.256  0.256
# 27                                  EOGVerticalSignal  0.728  0.170  0.170
# 28                                            FaceAll  0.864  0.513  0.235
# 29                                           FaceFour  0.741  0.281  0.483
# 30                                           FacesUCR  0.930  0.414  0.235
# 31                                          Fetal2013  0.781  0.553  0.333
# 32                                         FiftyWords  0.960  0.278  0.266
# 33                                               Fish  0.983  0.144  0.144
# 34                                FreezerRegularTrain  0.882  0.260  0.260
# 35                                   GrandMalSeizures  0.542  0.587  0.506
# 36                                  GrandMalSeizures2  0.761  0.508  0.508
# 37                                       GreatBarbet1  0.877  0.531  0.592
# 38                                       GreatBarbet2  0.817  0.792  0.729
# 39                                           GunPoint  0.864  0.501  0.501
# 40                                                Ham  0.641  0.251  0.249
# 41                                            Haptics  0.600  0.356  0.356
# 42                                            Herring  1.000  1.000  1.000
# 43                                        InlineSkate  0.358  0.358  0.358
# 44                                         InsectEPG1  0.751  0.255  0.657
# 45                                         InsectEPG2  0.981  0.925  0.715
# 46                                         InsectEPG3  0.997  0.894  0.641
# 47                                         InsectEPG4  0.987  0.537  0.728
# 48                                InsectWingbeatSound  0.915  0.686  0.468
# 49                                   ItalyPowerDemand  0.996  0.938  0.562
# 50                             LargeKitchenAppliances  0.333  0.333  0.330
# 51                                         Lightning2  0.556  0.556  0.921
# 52                                         Lightning7  0.798  0.215  0.448
# 53                                             Mallat  0.921  0.267  0.267
# 54                                               Meat  0.618  0.487  0.333
# 55                                      MedicalImages  0.580  0.580  0.580
# 56                                MelbournePedestrian  0.943  0.356  0.333
# 57                       MiddlePhalanxOutlineAgeGroup  0.802  0.249  0.250
# 58                        MiddlePhalanxOutlineCorrect  0.827  0.616  0.505
# 59                                    MiddlePhalanxTW  1.000  1.000  1.000
# 60                                         MoteStrain  0.897  0.500  0.500
# 61                                           NogunGun  0.802  0.823  0.518
# 62                         NonInvasiveFetalECGThorax1  0.791  0.555  0.169
# 63                         NonInvasiveFetalECGThorax2  0.991  0.513  0.146
# 64                                            OSULeaf  0.747  0.365  0.494
# 65                                           OliveOil  0.934  0.732  0.382
# 66           PigInternalBleedingDatasetAirwayPressure  0.483  0.500  0.223
# 67   PigInternalBleedingDatasetArtPressureFluidFilled  0.995  0.987  0.500
# 68                      PigInternalBleedingDatasetCVP  0.986  0.929  0.594
# 69                                              Plane  0.927  0.377  0.285
# 70                                        Powerdemand  0.335  0.278  0.515
# 71                     ProximalPhalanxOutlineAgeGroup  0.883  0.445  0.337
# 72                      ProximalPhalanxOutlineCorrect  0.559  0.530  0.601
# 73                                  ProximalPhalanxTW  0.971  0.497  0.457
# 74                                PulsusParadoxusECG1  1.000  0.510  0.510
# 75                                PulsusParadoxusECG2  0.824  0.676  0.510
# 76                                PulsusParadoxusSP02  0.665  0.808  0.510
# 77                                RoboticDogActivityX  0.996  0.666  0.412
# 78                                RoboticDogActivityY  0.997  0.711  0.374
# 79                                RoboticDogActivityZ  0.656  0.716  0.418
# 80                                        ShapeletSim  1.000  1.000  0.669
# 81                                          ShapesAll  0.962  0.740  0.200
# 82                                    SimpleSynthetic  0.995  0.344  0.344
# 83                              SonyAIBORobotSurface1  0.580  0.580  0.776
# 84                              SonyAIBORobotSurface2  0.972  0.517  0.601
# 85                                         Strawberry  0.332  0.332  0.466
# 86                                SuddenCardiacDeath1  0.683  0.465  0.415
# 87                                SuddenCardiacDeath2  0.992  0.475  0.605
# 88                                SuddenCardiacDeath3  0.942  0.484  0.605
# 89                                        SwedishLeaf  0.887  0.400  0.415
# 90                                            Symbols  0.518  0.297  0.297
# 91                                   SyntheticControl  0.978  0.362  0.275
# 92                                            TiltABP  0.445  0.288  0.531
# 93                                            TiltECG  0.916  0.487  0.531
# 94                                   ToeSegmentation1  0.761  0.500  0.730
# 95                                   ToeSegmentation2  0.891  0.500  0.500
# 96                                              Trace  0.652  0.644  0.344
# 97                                         TwoLeadECG  0.501  0.501  0.479
# 98                                                UMD  1.000  1.000  1.000
# 99                             UWaveGestureLibraryAll  0.994  0.201  0.351
# 100                              UWaveGestureLibraryX  0.985  0.201  0.366
# 101                              UWaveGestureLibraryY  0.774  0.201  0.393
# 102                              UWaveGestureLibraryZ  0.779  0.402  0.368
# 103                                       WalkJogRun1  0.864  0.412  0.337
# 104                                       WalkJogRun2  0.830  0.657  0.337
# 105                                      WordSynonyms  0.727  0.805  0.788
# 106                                              Yoga  0.504  0.561  0.502
#
#      Window
# 0     0.303
# 1     0.500
# 2     0.500
# 3     0.500
# 4     0.500
# 5     0.342
# 6     0.507
# 7     0.256
# 8     1.000
# 9     0.577
# 10    0.583
# 11    0.500
# 12    0.819
# 13    0.473
# 14    0.603
# 15    0.387
# 16    0.433
# 17    0.342
# 18    0.668
# 19    0.474
# 20    1.000
# 21    0.033
# 22    0.572
# 23    0.857
# 24    0.616
# 25    0.856
# 26    0.256
# 27    0.170
# 28    0.491
# 29    0.281
# 30    0.595
# 31    0.064
# 32    0.427
# 33    0.144
# 34    0.260
# 35    0.007
# 36    0.013
# 37    0.355
# 38    0.355
# 39    0.501
# 40    0.333
# 41    0.356
# 42    1.000
# 43    0.732
# 44    0.653
# 45    0.705
# 46    0.631
# 47    0.723
# 48    0.745
# 49    0.500
# 50    0.333
# 51    0.556
# 52    0.292
# 53    0.267
# 54    0.333
# 55    0.236
# 56    0.403
# 57    0.250
# 58    0.334
# 59    1.000
# 60    0.500
# 61    0.458
# 62    0.169
# 63    0.145
# 64    0.547
# 65    0.382
# 66    0.500
# 67    0.500
# 68    0.500
# 69    0.150
# 70    0.023
# 71    0.376
# 72    0.292
# 73    0.395
# 74    0.510
# 75    0.510
# 76    0.510
# 77    0.882
# 78    0.897
# 79    0.537
# 80    1.000
# 81    0.200
# 82    0.344
# 83    0.580
# 84    0.718
# 85    0.332
# 86    0.034
# 87    0.024
# 88    0.024
# 89    0.460
# 90    0.334
# 91    0.760
# 92    0.054
# 93    0.074
# 94    0.840
# 95    0.500
# 96    0.344
# 97    0.501
# 98    0.859
# 99    0.377
# 100   0.373
# 101   0.381
# 102   0.589
# 103   0.715
# 104   0.337
# 105   0.820
# 106   0.504

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2050/2219294936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0).round(3)
# ClaSS     0.812
# FLOSS     0.521
# BOCD      0.481
# Window    0.461
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2050/1729043111.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.median(axis=0).round(3)
# ClaSS     0.882
# FLOSS     0.500
# BOCD      0.494
# Window    0.474
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2050/1084607075.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0).round(3)
# ClaSS     0.190
# FLOSS     0.227
# BOCD      0.190
# Window    0.247
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 1)}")
# Out:
# ClaSS:wins=87 rank=1.2
# FLOSS:wins=15 rank=2.4
# BOCD:wins=12 rank=2.7
# Window:wins=15 rank=2.6

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4, filename=f"../../figures/cd_comparative_benchmark.pdf") #

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue
    
    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=False)
    
    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs FLOSS: (wins/ties/losses): 83/17/7
# ClaSS vs BOCD: (wins/ties/losses): 90/7/10
# ClaSS vs Window: (wins/ties/losses): 87/12/8

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10,5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)
    
ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0+.2,.2),1))
    
plt.savefig(f"../../figures/bp_comparative_benchmark.pdf", bbox_inches="tight")
