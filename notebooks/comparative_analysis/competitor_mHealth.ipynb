# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np

import pandas as pd

pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys

sys.path.append("../../")

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ADWIN", "HDDM", "NEWMA", "ChangeFinder", "DDM", "Window", "FLOSS", "ClaSS"]
dataset = "mHealth"
methods = list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))

for idx, (name, file_name) in enumerate(methods):
    methods[idx] = name, pd.read_csv(f"../../experiments/competitor_{dataset}/{file_name}",
                                     usecols=["dataset", eval_score], compression="gzip")

df_scores = pd.DataFrame()

for name, df in methods:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]

df_scores
# Out:
#                            dataset  ADWIN   HDDM  NEWMA  ChangeFinder    DDM  \
# 0     mHealth_Subject1_Ankle_X-Acc  0.497  0.447  0.086         0.536  0.086
# 1     mHealth_Subject1_Ankle_Y-Acc  0.625  0.277  0.086         0.347  0.086
# 2     mHealth_Subject1_Ankle_Z-Acc  0.566  0.357  0.086         0.495  0.173
# 3    mHealth_Subject1_Ankle_X-Gyro  0.591  0.302  0.086         0.435  0.240
# 4    mHealth_Subject1_Ankle_Y-Gyro  0.517  0.289  0.086         0.347  0.086
# 5    mHealth_Subject1_Ankle_Z-Gyro  0.552  0.276  0.086         0.260  0.171
# 6     mHealth_Subject1_Ankle_X-Mag  0.198  0.129  0.086         0.304  0.404
# 7     mHealth_Subject1_Ankle_Y-Mag  0.243  0.111  0.086         0.305  0.323
# 8     mHealth_Subject1_Ankle_Z-Mag  0.323  0.186  0.086         0.358  0.086
# 9     mHealth_Subject2_Ankle_X-Acc  0.509  0.633  0.087         0.346  0.087
# 10    mHealth_Subject2_Ankle_Y-Acc  0.524  0.366  0.087         0.458  0.087
# 11    mHealth_Subject2_Ankle_Z-Acc  0.568  0.319  0.087         0.526  0.087
# 12   mHealth_Subject2_Ankle_X-Gyro  0.589  0.393  0.087         0.528  0.202
# 13   mHealth_Subject2_Ankle_Y-Gyro  0.503  0.230  0.087         0.346  0.087
# 14   mHealth_Subject2_Ankle_Z-Gyro  0.698  0.467  0.087         0.526  0.166
# 15    mHealth_Subject2_Ankle_X-Mag  0.098  0.109  0.087         0.417  0.204
# 16    mHealth_Subject2_Ankle_Y-Mag  0.202  0.105  0.087         0.451  0.087
# 17    mHealth_Subject2_Ankle_Z-Mag  0.361  0.196  0.087         0.268  0.087
# 18    mHealth_Subject3_Ankle_X-Acc  0.497  0.547  0.087         0.417  0.164
# 19    mHealth_Subject3_Ankle_Y-Acc  0.529  0.338  0.087         0.335  0.087
# 20    mHealth_Subject3_Ankle_Z-Acc  0.443  0.371  0.087         0.386  0.167
# 21   mHealth_Subject3_Ankle_X-Gyro  0.631  0.384  0.087         0.610  0.282
# 22   mHealth_Subject3_Ankle_Y-Gyro  0.580  0.312  0.087         0.345  0.087
# 23   mHealth_Subject3_Ankle_Z-Gyro  0.667  0.440  0.087         0.610  0.172
# 24    mHealth_Subject3_Ankle_X-Mag  0.190  0.157  0.087         0.439  0.438
# 25    mHealth_Subject3_Ankle_Y-Mag  0.379  0.275  0.087         0.347  0.301
# 26    mHealth_Subject3_Ankle_Z-Mag  0.473  0.205  0.087         0.258  0.160
# 27    mHealth_Subject4_Ankle_X-Acc  0.512  0.531  0.087         0.347  0.172
# 28    mHealth_Subject4_Ankle_Y-Acc  0.473  0.281  0.087         0.408  0.087
# 29    mHealth_Subject4_Ankle_Z-Acc  0.480  0.322  0.087         0.494  0.170
# 30   mHealth_Subject4_Ankle_X-Gyro  0.754  0.424  0.087         0.732  0.181
# 31   mHealth_Subject4_Ankle_Y-Gyro  0.620  0.308  0.087         0.527  0.087
# 32   mHealth_Subject4_Ankle_Z-Gyro  0.654  0.441  0.087         0.698  0.316
# 33    mHealth_Subject4_Ankle_X-Mag  0.107  0.148  0.087         0.544  0.283
# 34    mHealth_Subject4_Ankle_Y-Mag  0.249  0.204  0.087         0.394  0.087
# 35    mHealth_Subject4_Ankle_Z-Mag  0.410  0.195  0.087         0.261  0.120
# 36    mHealth_Subject5_Ankle_X-Acc  0.457  0.352  0.087         0.420  0.169
# 37    mHealth_Subject5_Ankle_Y-Acc  0.598  0.278  0.087         0.420  0.087
# 38    mHealth_Subject5_Ankle_Z-Acc  0.546  0.402  0.087         0.436  0.087
# 39   mHealth_Subject5_Ankle_X-Gyro  0.624  0.393  0.087         0.530  0.087
# 40   mHealth_Subject5_Ankle_Y-Gyro  0.633  0.258  0.087         0.266  0.087
# 41   mHealth_Subject5_Ankle_Z-Gyro  0.660  0.463  0.087         0.527  0.336
# 42    mHealth_Subject5_Ankle_X-Mag  0.200  0.111  0.087         0.513  0.294
# 43    mHealth_Subject5_Ankle_Y-Mag  0.397  0.131  0.087         0.427  0.170
# 44    mHealth_Subject5_Ankle_Z-Mag  0.420  0.194  0.087         0.409  0.087
# 45    mHealth_Subject6_Ankle_X-Acc  0.569  0.400  0.088         0.443  0.088
# 46    mHealth_Subject6_Ankle_Y-Acc  0.708  0.273  0.088         0.443  0.088
# 47    mHealth_Subject6_Ankle_Z-Acc  0.573  0.364  0.088         0.452  0.088
# 48   mHealth_Subject6_Ankle_X-Gyro  0.627  0.335  0.088         0.371  0.088
# 49   mHealth_Subject6_Ankle_Y-Gyro  0.648  0.391  0.088         0.371  0.088
# 50   mHealth_Subject6_Ankle_Z-Gyro  0.655  0.323  0.088         0.456  0.173
# 51    mHealth_Subject6_Ankle_X-Mag  0.247  0.136  0.088         0.446  0.364
# 52    mHealth_Subject6_Ankle_Y-Mag  0.356  0.175  0.088         0.439  0.297
# 53    mHealth_Subject6_Ankle_Z-Mag  0.507  0.173  0.088         0.494  0.170
# 54    mHealth_Subject7_Ankle_X-Acc  0.557  0.428  0.087         0.524  0.164
# 55    mHealth_Subject7_Ankle_Y-Acc  0.496  0.282  0.087         0.354  0.087
# 56    mHealth_Subject7_Ankle_Z-Acc  0.502  0.287  0.087         0.418  0.173
# 57   mHealth_Subject7_Ankle_X-Gyro  0.718  0.310  0.087         0.515  0.087
# 58   mHealth_Subject7_Ankle_Y-Gyro  0.606  0.248  0.087         0.347  0.087
# 59   mHealth_Subject7_Ankle_Z-Gyro  0.680  0.435  0.087         0.524  0.241
# 60    mHealth_Subject7_Ankle_X-Mag  0.177  0.146  0.087         0.447  0.332
# 61    mHealth_Subject7_Ankle_Y-Mag  0.267  0.183  0.087         0.343  0.243
# 62    mHealth_Subject7_Ankle_Z-Mag  0.357  0.194  0.087         0.260  0.086
# 63    mHealth_Subject8_Ankle_X-Acc  0.483  0.414  0.087         0.439  0.087
# 64    mHealth_Subject8_Ankle_Y-Acc  0.604  0.279  0.087         0.531  0.087
# 65    mHealth_Subject8_Ankle_Z-Acc  0.533  0.279  0.087         0.447  0.176
# 66   mHealth_Subject8_Ankle_X-Gyro  0.600  0.296  0.087         0.445  0.232
# 67   mHealth_Subject8_Ankle_Y-Gyro  0.620  0.303  0.087         0.361  0.164
# 68   mHealth_Subject8_Ankle_Z-Gyro  0.715  0.318  0.087         0.447  0.087
# 69    mHealth_Subject8_Ankle_X-Mag  0.180  0.134  0.087         0.404  0.177
# 70    mHealth_Subject8_Ankle_Y-Mag  0.396  0.218  0.087         0.372  0.169
# 71    mHealth_Subject8_Ankle_Z-Mag  0.367  0.219  0.087         0.460  0.087
# 72    mHealth_Subject9_Ankle_X-Acc  0.539  0.358  0.086         0.341  0.086
# 73    mHealth_Subject9_Ankle_Y-Acc  0.606  0.363  0.086         0.517  0.086
# 74    mHealth_Subject9_Ankle_Z-Acc  0.543  0.381  0.086         0.518  0.171
# 75   mHealth_Subject9_Ankle_X-Gyro  0.687  0.318  0.086         0.438  0.173
# 76   mHealth_Subject9_Ankle_Y-Gyro  0.661  0.336  0.086         0.439  0.086
# 77   mHealth_Subject9_Ankle_Z-Gyro  0.694  0.357  0.086         0.612  0.086
# 78    mHealth_Subject9_Ankle_X-Mag  0.172  0.156  0.086         0.437  0.291
# 79    mHealth_Subject9_Ankle_Y-Mag  0.386  0.150  0.086         0.459  0.278
# 80    mHealth_Subject9_Ankle_Z-Mag  0.372  0.186  0.086         0.330  0.086
# 81   mHealth_Subject10_Ankle_X-Acc  0.529  0.578  0.087         0.350  0.171
# 82   mHealth_Subject10_Ankle_Y-Acc  0.465  0.313  0.087         0.414  0.087
# 83   mHealth_Subject10_Ankle_Z-Acc  0.554  0.366  0.087         0.375  0.167
# 84  mHealth_Subject10_Ankle_X-Gyro  0.574  0.272  0.087         0.268  0.208
# 85  mHealth_Subject10_Ankle_Y-Gyro  0.623  0.320  0.087         0.266  0.087
# 86  mHealth_Subject10_Ankle_Z-Gyro  0.659  0.434  0.087         0.442  0.240
# 87   mHealth_Subject10_Ankle_X-Mag  0.178  0.194  0.087         0.483  0.361
# 88   mHealth_Subject10_Ankle_Y-Mag  0.370  0.229  0.087         0.420  0.087
# 89   mHealth_Subject10_Ankle_Z-Mag  0.305  0.189  0.087         0.412  0.087
#
#     Window  FLOSS  ClaSS
# 0    0.311  0.331  0.601
# 1    0.390  0.279  0.758
# 2    0.413  0.307  0.750
# 3    0.086  0.456  0.607
# 4    0.086  0.354  0.694
# 5    0.086  0.389  0.766
# 6    0.226  0.284  0.797
# 7    0.182  0.334  0.602
# 8    0.230  0.269  0.741
# 9    0.306  0.406  0.545
# 10   0.397  0.359  0.652
# 11   0.420  0.355  0.580
# 12   0.087  0.474  0.538
# 13   0.087  0.380  0.671
# 14   0.087  0.415  0.592
# 15   0.308  0.334  0.649
# 16   0.196  0.470  0.601
# 17   0.271  0.453  0.639
# 18   0.279  0.360  0.642
# 19   0.387  0.310  0.455
# 20   0.345  0.330  0.610
# 21   0.087  0.423  0.640
# 22   0.087  0.361  0.660
# 23   0.087  0.300  0.610
# 24   0.250  0.388  0.772
# 25   0.243  0.266  0.751
# 26   0.305  0.401  0.733
# 27   0.290  0.417  0.479
# 28   0.351  0.348  0.643
# 29   0.316  0.391  0.671
# 30   0.087  0.404  0.808
# 31   0.087  0.372  0.636
# 32   0.087  0.336  0.680
# 33   0.244  0.366  0.771
# 34   0.250  0.382  0.610
# 35   0.341  0.336  0.845
# 36   0.235  0.378  0.686
# 37   0.354  0.347  0.710
# 38   0.316  0.350  0.673
# 39   0.087  0.312  0.663
# 40   0.087  0.344  0.765
# 41   0.087  0.347  0.706
# 42   0.235  0.331  0.911
# 43   0.229  0.356  0.869
# 44   0.297  0.273  0.912
# 45   0.248  0.292  0.657
# 46   0.422  0.377  0.651
# 47   0.225  0.290  0.624
# 48   0.088  0.361  0.712
# 49   0.088  0.382  0.648
# 50   0.088  0.294  0.656
# 51   0.260  0.317  0.803
# 52   0.220  0.338  0.622
# 53   0.235  0.291  0.673
# 54   0.303  0.322  0.636
# 55   0.245  0.377  0.527
# 56   0.226  0.313  0.688
# 57   0.087  0.295  0.451
# 58   0.087  0.318  0.575
# 59   0.087  0.387  0.664
# 60   0.235  0.329  0.736
# 61   0.277  0.433  0.567
# 62   0.215  0.299  0.545
# 63   0.294  0.302  0.556
# 64   0.403  0.278  0.586
# 65   0.531  0.308  0.569
# 66   0.087  0.269  0.587
# 67   0.087  0.317  0.517
# 68   0.087  0.323  0.673
# 69   0.251  0.278  0.635
# 70   0.255  0.362  0.744
# 71   0.276  0.287  0.713
# 72   0.214  0.399  0.763
# 73   0.305  0.296  0.707
# 74   0.255  0.340  0.653
# 75   0.086  0.261  0.790
# 76   0.086  0.306  0.741
# 77   0.086  0.346  0.757
# 78   0.220  0.277  0.819
# 79   0.212  0.344  0.756
# 80   0.218  0.294  0.859
# 81   0.389  0.317  0.522
# 82   0.331  0.313  0.601
# 83   0.285  0.327  0.575
# 84   0.087  0.386  0.659
# 85   0.087  0.348  0.601
# 86   0.087  0.336  0.593
# 87   0.308  0.367  0.724
# 88   0.306  0.413  0.722
# 89   0.226  0.391  0.713

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4045/3088260556.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0).round(3)
# ADWIN           0.489
# HDDM            0.297
# NEWMA           0.087
# ChangeFinder    0.427
# DDM             0.162
# Window          0.221
# FLOSS           0.344
# ClaSS           0.670
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4045/803467923.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.median(axis=0).round(3)
# ADWIN           0.526
# HDDM            0.299
# NEWMA           0.087
# ChangeFinder    0.436
# DDM             0.164
# Window          0.235
# FLOSS           0.339
# ClaSS           0.660
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4045/2527189798.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0).round(3)
# ADWIN           0.163
# HDDM            0.114
# NEWMA           0.001
# ChangeFinder    0.095
# DDM             0.090
# Window          0.111
# FLOSS           0.049
# ClaSS           0.096
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method='min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 5)}")
# Out:
# ADWIN:wins=15 rank=2.58889
# HDDM:wins=3 rank=5.01111
# NEWMA:wins=0 rank=7.2
# ChangeFinder:wins=1 rank=3.13333
# DDM:wins=0 rank=6.16667
# Window:wins=0 rank=5.47778
# FLOSS:wins=0 rank=4.21111
# ClaSS:wins=72 rank=1.23333

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4,
                                      filename=f"../../figures/cd_comparative_{dataset}.pdf")  #

# %% [markdown]
# Let's compute wins/losses against ClaSS.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue

    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method='min', ascending=False)

    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]

    assert wins + losses + ties == pair_ranks.shape[0]

    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs ADWIN: (wins/ties/losses): 73/1/16
# ClaSS vs HDDM: (wins/ties/losses): 87/0/3
# ClaSS vs NEWMA: (wins/ties/losses): 90/0/0
# ClaSS vs ChangeFinder: (wins/ties/losses): 87/1/2
# ClaSS vs DDM: (wins/ties/losses): 90/0/0
# ClaSS vs Window: (wins/ties/losses): 90/0/0
# ClaSS vs FLOSS: (wins/ties/losses): 90/0/0

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10, 5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0 + .2, .2), 1))

plt.savefig(f"../../figures/bp_comparative_{dataset}.pdf", bbox_inches="tight")
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4045/3898032719.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4045/3898032719.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
