# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../../")

from tqdm import tqdm

# %%
from src.visualizer import plot_profile, plot_profile_with_ts

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ADWIN", "HDDM", "NEWMA", "ChangeFinder", "DDM", "Window", "FLOSS", "ClaSS"]
dataset = "mHealth"
methods = list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))

for idx, (name, file_name) in enumerate(methods):
    methods[idx] = name, pd.read_csv(f"../../experiments/competitor_{dataset}/{file_name}", usecols=["dataset", eval_score], compression="gzip")
    
df_scores = pd.DataFrame()

for name, df in methods:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]
    
df_scores
# Out:
#                            dataset  ClaSS  FLOSS  Window
# 0     mHealth_Subject1_Ankle_X-Acc  0.601  0.331   0.311
# 1     mHealth_Subject1_Ankle_Y-Acc  0.758  0.279   0.390
# 2     mHealth_Subject1_Ankle_Z-Acc  0.750  0.307   0.413
# 3    mHealth_Subject1_Ankle_X-Gyro  0.607  0.456   0.086
# 4    mHealth_Subject1_Ankle_Y-Gyro  0.694  0.354   0.086
# 5    mHealth_Subject1_Ankle_Z-Gyro  0.766  0.389   0.086
# 6     mHealth_Subject1_Ankle_X-Mag  0.797  0.284   0.226
# 7     mHealth_Subject1_Ankle_Y-Mag  0.602  0.334   0.182
# 8     mHealth_Subject1_Ankle_Z-Mag  0.741  0.269   0.230
# 9     mHealth_Subject2_Ankle_X-Acc  0.545  0.406   0.306
# 10    mHealth_Subject2_Ankle_Y-Acc  0.652  0.359   0.397
# 11    mHealth_Subject2_Ankle_Z-Acc  0.580  0.355   0.420
# 12   mHealth_Subject2_Ankle_X-Gyro  0.538  0.474   0.087
# 13   mHealth_Subject2_Ankle_Y-Gyro  0.671  0.380   0.087
# 14   mHealth_Subject2_Ankle_Z-Gyro  0.592  0.415   0.087
# 15    mHealth_Subject2_Ankle_X-Mag  0.649  0.334   0.308
# 16    mHealth_Subject2_Ankle_Y-Mag  0.601  0.470   0.196
# 17    mHealth_Subject2_Ankle_Z-Mag  0.639  0.453   0.271
# 18    mHealth_Subject3_Ankle_X-Acc  0.642  0.360   0.279
# 19    mHealth_Subject3_Ankle_Y-Acc  0.455  0.310   0.387
# 20    mHealth_Subject3_Ankle_Z-Acc  0.610  0.330   0.345
# 21   mHealth_Subject3_Ankle_X-Gyro  0.640  0.423   0.087
# 22   mHealth_Subject3_Ankle_Y-Gyro  0.660  0.361   0.087
# 23   mHealth_Subject3_Ankle_Z-Gyro  0.610  0.300   0.087
# 24    mHealth_Subject3_Ankle_X-Mag  0.772  0.388   0.250
# 25    mHealth_Subject3_Ankle_Y-Mag  0.751  0.266   0.243
# 26    mHealth_Subject3_Ankle_Z-Mag  0.733  0.401   0.305
# 27    mHealth_Subject4_Ankle_X-Acc  0.479  0.417   0.290
# 28    mHealth_Subject4_Ankle_Y-Acc  0.643  0.348   0.351
# 29    mHealth_Subject4_Ankle_Z-Acc  0.671  0.391   0.316
# 30   mHealth_Subject4_Ankle_X-Gyro  0.808  0.404   0.087
# 31   mHealth_Subject4_Ankle_Y-Gyro  0.636  0.372   0.087
# 32   mHealth_Subject4_Ankle_Z-Gyro  0.680  0.336   0.087
# 33    mHealth_Subject4_Ankle_X-Mag  0.771  0.366   0.244
# 34    mHealth_Subject4_Ankle_Y-Mag  0.610  0.382   0.250
# 35    mHealth_Subject4_Ankle_Z-Mag  0.845  0.336   0.341
# 36    mHealth_Subject5_Ankle_X-Acc  0.686  0.378   0.235
# 37    mHealth_Subject5_Ankle_Y-Acc  0.710  0.347   0.354
# 38    mHealth_Subject5_Ankle_Z-Acc  0.673  0.350   0.316
# 39   mHealth_Subject5_Ankle_X-Gyro  0.663  0.312   0.087
# 40   mHealth_Subject5_Ankle_Y-Gyro  0.765  0.344   0.087
# 41   mHealth_Subject5_Ankle_Z-Gyro  0.706  0.347   0.087
# 42    mHealth_Subject5_Ankle_X-Mag  0.911  0.331   0.235
# 43    mHealth_Subject5_Ankle_Y-Mag  0.869  0.356   0.229
# 44    mHealth_Subject5_Ankle_Z-Mag  0.912  0.273   0.297
# 45    mHealth_Subject6_Ankle_X-Acc  0.657  0.292   0.248
# 46    mHealth_Subject6_Ankle_Y-Acc  0.651  0.377   0.422
# 47    mHealth_Subject6_Ankle_Z-Acc  0.624  0.290   0.225
# 48   mHealth_Subject6_Ankle_X-Gyro  0.712  0.361   0.088
# 49   mHealth_Subject6_Ankle_Y-Gyro  0.648  0.382   0.088
# 50   mHealth_Subject6_Ankle_Z-Gyro  0.656  0.294   0.088
# 51    mHealth_Subject6_Ankle_X-Mag  0.803  0.317   0.260
# 52    mHealth_Subject6_Ankle_Y-Mag  0.622  0.338   0.220
# 53    mHealth_Subject6_Ankle_Z-Mag  0.673  0.291   0.235
# 54    mHealth_Subject7_Ankle_X-Acc  0.636  0.322   0.303
# 55    mHealth_Subject7_Ankle_Y-Acc  0.527  0.377   0.245
# 56    mHealth_Subject7_Ankle_Z-Acc  0.688  0.313   0.226
# 57   mHealth_Subject7_Ankle_X-Gyro  0.451  0.295   0.087
# 58   mHealth_Subject7_Ankle_Y-Gyro  0.575  0.318   0.087
# 59   mHealth_Subject7_Ankle_Z-Gyro  0.664  0.387   0.087
# 60    mHealth_Subject7_Ankle_X-Mag  0.736  0.329   0.235
# 61    mHealth_Subject7_Ankle_Y-Mag  0.567  0.433   0.277
# 62    mHealth_Subject7_Ankle_Z-Mag  0.545  0.299   0.215
# 63    mHealth_Subject8_Ankle_X-Acc  0.556  0.302   0.294
# 64    mHealth_Subject8_Ankle_Y-Acc  0.586  0.278   0.403
# 65    mHealth_Subject8_Ankle_Z-Acc  0.569  0.308   0.531
# 66   mHealth_Subject8_Ankle_X-Gyro  0.587  0.269   0.087
# 67   mHealth_Subject8_Ankle_Y-Gyro  0.517  0.317   0.087
# 68   mHealth_Subject8_Ankle_Z-Gyro  0.673  0.323   0.087
# 69    mHealth_Subject8_Ankle_X-Mag  0.635  0.278   0.251
# 70    mHealth_Subject8_Ankle_Y-Mag  0.744  0.362   0.255
# 71    mHealth_Subject8_Ankle_Z-Mag  0.713  0.287   0.276
# 72    mHealth_Subject9_Ankle_X-Acc  0.763  0.399   0.214
# 73    mHealth_Subject9_Ankle_Y-Acc  0.707  0.296   0.305
# 74    mHealth_Subject9_Ankle_Z-Acc  0.653  0.340   0.255
# 75   mHealth_Subject9_Ankle_X-Gyro  0.790  0.261   0.086
# 76   mHealth_Subject9_Ankle_Y-Gyro  0.741  0.306   0.086
# 77   mHealth_Subject9_Ankle_Z-Gyro  0.757  0.346   0.086
# 78    mHealth_Subject9_Ankle_X-Mag  0.819  0.277   0.220
# 79    mHealth_Subject9_Ankle_Y-Mag  0.756  0.344   0.212
# 80    mHealth_Subject9_Ankle_Z-Mag  0.859  0.294   0.218
# 81   mHealth_Subject10_Ankle_X-Acc  0.522  0.317   0.389
# 82   mHealth_Subject10_Ankle_Y-Acc  0.601  0.313   0.331
# 83   mHealth_Subject10_Ankle_Z-Acc  0.575  0.327   0.285
# 84  mHealth_Subject10_Ankle_X-Gyro  0.659  0.386   0.087
# 85  mHealth_Subject10_Ankle_Y-Gyro  0.601  0.348   0.087
# 86  mHealth_Subject10_Ankle_Z-Gyro  0.593  0.336   0.087
# 87   mHealth_Subject10_Ankle_X-Mag  0.724  0.367   0.308
# 88   mHealth_Subject10_Ankle_Y-Mag  0.722  0.413   0.306
# 89   mHealth_Subject10_Ankle_Z-Mag  0.713  0.391   0.226

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_1179/2219294936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0).round(3)
# ClaSS     0.670
# FLOSS     0.344
# Window    0.221
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_1179/1729043111.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.median(axis=0).round(3)
# ClaSS     0.660
# FLOSS     0.339
# Window    0.235
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_1179/1084607075.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0).round(3)
# ClaSS     0.096
# FLOSS     0.049
# Window    0.111
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 5)}")
# Out:
# ClaSS:wins=90 rank=1.0
# FLOSS:wins=0 rank=2.17778
# Window:wins=0 rank=2.82222

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4, filename=f"../../figures/cd_comparative_{dataset}.pdf") #

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue
    
    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=False)
    
    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs FLOSS: (wins/ties/losses): 90/0/0
# ClaSS vs Window: (wins/ties/losses): 90/0/0

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10,5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)
    
ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0+.2,.2),1))
    
plt.savefig(f"../../figures/bp_comparative_{dataset}.pdf", bbox_inches="tight")
