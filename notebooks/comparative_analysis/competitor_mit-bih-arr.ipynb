# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np

import pandas as pd

pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys

sys.path.append("../../")

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ADWIN", "HDDM", "NEWMA", "ChangeFinder", "DDM", "Window", "FLOSS", "ClaSS"]
dataset = "MIT-BIH-Arr"
methods = list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))

for idx, (name, file_name) in enumerate(methods):
    methods[idx] = name, pd.read_csv(f"../../experiments/competitor_{dataset}/{file_name}",
                                     usecols=["dataset", eval_score], compression="gzip")

df_scores = pd.DataFrame()

for name, df in methods:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]

df_scores
# Out:
#                         dataset  ADWIN   HDDM  NEWMA  ChangeFinder    DDM  \
# 0   MIT-BIH-Arr_MLII_Subject100  0.041  1.000  1.000         0.167  1.000
# 1     MIT-BIH-Arr_V5_Subject100  0.039  0.452  1.000         0.349  1.000
# 2   MIT-BIH-Arr_MLII_Subject101  0.040  0.714  1.000         0.304  1.000
# 3     MIT-BIH-Arr_V1_Subject101  0.017  0.961  1.000         0.360  1.000
# 4     MIT-BIH-Arr_V5_Subject102  0.069  0.819  0.819         0.075  0.819
# 5     MIT-BIH-Arr_V2_Subject102  0.434  0.045  0.819         0.207  0.259
# 6   MIT-BIH-Arr_MLII_Subject103  0.035  0.605  1.000         0.463  1.000
# 7     MIT-BIH-Arr_V2_Subject103  0.053  0.610  1.000         0.590  0.334
# 8     MIT-BIH-Arr_V5_Subject104  0.257  0.322  0.242         0.178  0.242
# 9     MIT-BIH-Arr_V2_Subject104  0.267  0.363  0.242         0.183  0.286
# 10  MIT-BIH-Arr_MLII_Subject105  0.066  0.470  1.000         0.669  1.000
# 11    MIT-BIH-Arr_V1_Subject105  0.018  0.145  1.000         0.136  1.000
# 12  MIT-BIH-Arr_MLII_Subject106  0.297  0.353  0.126         0.169  0.126
# 13    MIT-BIH-Arr_V1_Subject106  0.240  0.252  0.126         0.408  0.368
# 14  MIT-BIH-Arr_MLII_Subject107  0.066  0.016  1.000         0.049  1.000
# 15    MIT-BIH-Arr_V1_Subject107  0.115  0.102  1.000         0.051  0.989
# 16  MIT-BIH-Arr_MLII_Subject108  0.026  0.188  1.000         0.092  1.000
# 17    MIT-BIH-Arr_V1_Subject108  0.025  0.059  1.000         0.034  0.338
# 18  MIT-BIH-Arr_MLII_Subject109  0.169  0.872  1.000         0.339  1.000
# 19    MIT-BIH-Arr_V1_Subject109  0.057  0.602  1.000         0.209  0.987
# 20  MIT-BIH-Arr_MLII_Subject111  0.026  0.134  1.000         0.125  1.000
# 21    MIT-BIH-Arr_V1_Subject111  0.042  0.192  1.000         0.128  0.999
# 22  MIT-BIH-Arr_MLII_Subject112  0.032  0.444  1.000         0.222  1.000
# 23    MIT-BIH-Arr_V1_Subject112  0.014  0.693  1.000         0.035  1.000
# 24  MIT-BIH-Arr_MLII_Subject113  0.063  0.454  1.000         0.029  1.000
# 25    MIT-BIH-Arr_V1_Subject113  0.024  0.453  1.000         0.034  0.842
# 26    MIT-BIH-Arr_V5_Subject114  0.032  0.431  0.522         0.205  0.522
# 27  MIT-BIH-Arr_MLII_Subject114  0.106  0.473  0.522         0.287  0.522
# 28  MIT-BIH-Arr_MLII_Subject115  0.046  0.110  1.000         0.113  1.000
# 29    MIT-BIH-Arr_V1_Subject115  0.017  0.323  1.000         0.045  1.000
# 30  MIT-BIH-Arr_MLII_Subject116  0.068  0.074  1.000         0.222  1.000
# 31    MIT-BIH-Arr_V1_Subject116  0.023  0.070  1.000         0.283  1.000
# 32  MIT-BIH-Arr_MLII_Subject117  0.042  0.232  1.000         0.110  1.000
# 33    MIT-BIH-Arr_V2_Subject117  0.022  0.088  1.000         0.081  1.000
# 34  MIT-BIH-Arr_MLII_Subject118  0.048  0.157  1.000         0.128  1.000
# 35    MIT-BIH-Arr_V1_Subject118  0.025  0.090  1.000         0.056  1.000
# 36  MIT-BIH-Arr_MLII_Subject119  0.417  0.372  0.029         0.333  0.029
# 37    MIT-BIH-Arr_V1_Subject119  0.355  0.310  0.029         0.394  0.029
# 38  MIT-BIH-Arr_MLII_Subject121  0.018  0.267  1.000         0.073  1.000
# 39    MIT-BIH-Arr_V1_Subject121  0.019  0.095  1.000         0.054  1.000
# 40  MIT-BIH-Arr_MLII_Subject122  0.072  0.523  1.000         0.897  1.000
# 41    MIT-BIH-Arr_V1_Subject122  0.013  0.342  1.000         0.470  1.000
# 42  MIT-BIH-Arr_MLII_Subject123  0.058  0.520  1.000         0.167  1.000
# 43    MIT-BIH-Arr_V5_Subject123  0.022  0.250  1.000         0.025  1.000
# 44  MIT-BIH-Arr_MLII_Subject124  0.141  0.289  0.184         0.176  0.184
# 45    MIT-BIH-Arr_V4_Subject124  0.064  0.352  0.184         0.145  0.184
# 46  MIT-BIH-Arr_MLII_Subject200  0.423  0.126  0.022         0.380  0.022
# 47    MIT-BIH-Arr_V1_Subject200  0.311  0.134  0.022         0.308  0.097
# 48  MIT-BIH-Arr_MLII_Subject201  0.318  0.192  0.090         0.245  0.090
# 49    MIT-BIH-Arr_V1_Subject201  0.344  0.276  0.090         0.327  0.090
# 50  MIT-BIH-Arr_MLII_Subject202  0.141  0.316  0.437         0.271  0.437
# 51    MIT-BIH-Arr_V1_Subject202  0.141  0.313  0.437         0.277  0.319
# 52  MIT-BIH-Arr_MLII_Subject203  0.224  0.250  0.091         0.210  0.091
# 53    MIT-BIH-Arr_V1_Subject203  0.255  0.310  0.091         0.419  0.370
# 54  MIT-BIH-Arr_MLII_Subject205  0.143  0.428  0.265         0.775  0.265
# 55    MIT-BIH-Arr_V1_Subject205  0.052  0.566  0.265         0.778  0.265
# 56  MIT-BIH-Arr_MLII_Subject207  0.118  0.503  0.493         0.184  0.493
# 57    MIT-BIH-Arr_V1_Subject207  0.079  0.604  0.493         0.216  0.641
# 58  MIT-BIH-Arr_MLII_Subject208  0.284  0.315  0.104         0.273  0.104
# 59    MIT-BIH-Arr_V1_Subject208  0.304  0.454  0.104         0.316  0.104
# 60  MIT-BIH-Arr_MLII_Subject209  0.176  0.605  0.211         0.584  0.211
# 61    MIT-BIH-Arr_V1_Subject209  0.098  0.211  0.211         0.342  0.211
# 62  MIT-BIH-Arr_MLII_Subject210  0.147  0.446  0.214         0.583  0.214
# 63    MIT-BIH-Arr_V1_Subject210  0.091  0.451  0.214         0.333  0.214
# 64  MIT-BIH-Arr_MLII_Subject212  0.035  0.197  1.000         0.373  1.000
# 65    MIT-BIH-Arr_V1_Subject212  0.056  0.155  1.000         0.186  0.999
# 66  MIT-BIH-Arr_MLII_Subject213  0.189  0.259  0.091         0.495  0.091
# 67    MIT-BIH-Arr_V1_Subject213  0.387  0.359  0.091         0.395  0.091
# 68  MIT-BIH-Arr_MLII_Subject214  0.284  0.409  0.106         0.353  0.106
# 69    MIT-BIH-Arr_V1_Subject214  0.166  0.431  0.106         0.257  0.322
# 70  MIT-BIH-Arr_MLII_Subject215  0.081  0.391  0.449         0.491  0.449
# 71    MIT-BIH-Arr_V1_Subject215  0.037  0.383  0.449         0.542  0.475
# 72  MIT-BIH-Arr_MLII_Subject217  0.357  0.389  0.077         0.267  0.077
# 73    MIT-BIH-Arr_V1_Subject217  0.281  0.077  0.077         0.256  0.079
# 74  MIT-BIH-Arr_MLII_Subject219  0.127  0.263  0.159         0.196  0.159
# 75    MIT-BIH-Arr_V1_Subject219  0.073  0.164  0.159         0.293  0.159
# 76  MIT-BIH-Arr_MLII_Subject220  0.169  0.541  0.269         0.348  0.269
# 77    MIT-BIH-Arr_V1_Subject220  0.094  0.399  0.269         0.139  0.269
# 78  MIT-BIH-Arr_MLII_Subject221  0.182  0.365  0.238         0.189  0.238
# 79    MIT-BIH-Arr_V1_Subject221  0.177  0.522  0.238         0.314  0.238
# 80  MIT-BIH-Arr_MLII_Subject222  0.287  0.343  0.103         0.272  0.103
# 81    MIT-BIH-Arr_V1_Subject222  0.292  0.301  0.103         0.316  0.085
# 82  MIT-BIH-Arr_MLII_Subject223  0.296  0.363  0.104         0.494  0.104
# 83    MIT-BIH-Arr_V1_Subject223  0.260  0.322  0.104         0.427  0.104
# 84  MIT-BIH-Arr_MLII_Subject228  0.292  0.227  0.070         0.247  0.070
# 85    MIT-BIH-Arr_V1_Subject228  0.384  0.338  0.070         0.288  0.070
# 86  MIT-BIH-Arr_MLII_Subject230  0.365  0.194  0.027         0.171  0.027
# 87    MIT-BIH-Arr_V1_Subject230  0.346  0.116  0.027         0.252  0.092
# 88  MIT-BIH-Arr_MLII_Subject231  0.210  0.506  0.128         0.121  0.128
# 89    MIT-BIH-Arr_V1_Subject231  0.140  0.548  0.128         0.422  0.271
# 90  MIT-BIH-Arr_MLII_Subject232  0.026  0.367  1.000         0.008  1.000
# 91    MIT-BIH-Arr_V1_Subject232  0.028  0.143  1.000         0.038  0.604
# 92  MIT-BIH-Arr_MLII_Subject233  0.311  0.405  0.064         0.419  0.064
# 93    MIT-BIH-Arr_V1_Subject233  0.340  0.337  0.064         0.136  0.082
# 94  MIT-BIH-Arr_MLII_Subject234  0.062  0.294  0.487         0.575  0.487
# 95    MIT-BIH-Arr_V1_Subject234  0.062  0.365  0.487         0.238  0.487
#
#     Window  FLOSS  ClaSS
# 0    1.000  0.500  0.659
# 1    1.000  0.531  0.623
# 2    1.000  0.234  0.516
# 3    1.000  0.140  0.132
# 4    0.819  0.870  0.987
# 5    0.819  0.867  0.581
# 6    1.000  0.291  0.329
# 7    1.000  0.175  0.387
# 8    0.242  0.436  0.543
# 9    0.242  0.469  0.509
# 10   1.000  0.123  0.306
# 11   1.000  0.070  0.275
# 12   0.126  0.306  0.372
# 13   0.126  0.375  0.380
# 14   1.000  0.148  0.442
# 15   1.000  0.144  0.256
# 16   1.000  0.098  0.186
# 17   1.000  0.047  0.219
# 18   1.000  0.536  0.267
# 19   1.000  0.336  0.182
# 20   1.000  0.083  0.276
# 21   1.000  0.093  0.289
# 22   1.000  0.228  0.389
# 23   1.000  0.291  0.272
# 24   1.000  0.390  0.540
# 25   1.000  0.331  0.184
# 26   0.522  0.108  0.435
# 27   0.522  0.326  0.527
# 28   1.000  0.189  0.575
# 29   1.000  0.288  0.713
# 30   1.000  0.136  0.283
# 31   1.000  0.134  0.416
# 32   1.000  0.440  0.576
# 33   1.000  0.586  0.598
# 34   1.000  0.126  0.197
# 35   1.000  0.127  0.212
# 36   0.029  0.415  0.347
# 37   0.029  0.252  0.185
# 38   1.000  0.121  0.405
# 39   1.000  0.055  0.329
# 40   1.000  0.048  0.377
# 41   1.000  0.197  0.581
# 42   1.000  0.135  0.999
# 43   1.000  0.121  0.640
# 44   0.184  0.413  0.648
# 45   0.184  0.648  0.787
# 46   0.022  0.444  0.248
# 47   0.022  0.316  0.243
# 48   0.090  0.461  0.446
# 49   0.090  0.444  0.439
# 50   0.437  0.480  0.727
# 51   0.437  0.533  0.574
# 52   0.091  0.355  0.442
# 53   0.091  0.385  0.136
# 54   0.265  0.441  0.859
# 55   0.265  0.499  0.856
# 56   0.493  0.297  0.281
# 57   0.493  0.281  0.431
# 58   0.104  0.307  0.344
# 59   0.104  0.368  0.259
# 60   0.211  0.556  0.620
# 61   0.211  0.328  0.535
# 62   0.214  0.601  0.605
# 63   0.214  0.443  0.419
# 64   1.000  0.084  0.101
# 65   1.000  0.069  0.100
# 66   0.091  0.540  0.241
# 67   0.091  0.535  0.477
# 68   0.106  0.479  0.431
# 69   0.106  0.464  0.468
# 70   0.449  0.674  0.417
# 71   0.449  0.202  0.434
# 72   0.077  0.451  0.551
# 73   0.077  0.460  0.519
# 74   0.159  0.582  0.588
# 75   0.159  0.502  0.571
# 76   0.269  0.379  0.676
# 77   0.269  0.403  0.269
# 78   0.238  0.238  0.238
# 79   0.238  0.555  0.238
# 80   0.103  0.482  0.422
# 81   0.103  0.354  0.514
# 82   0.104  0.514  0.714
# 83   0.104  0.617  0.736
# 84   0.070  0.642  0.624
# 85   0.070  0.609  0.600
# 86   0.027  0.457  0.584
# 87   0.027  0.440  0.597
# 88   0.128  0.815  0.945
# 89   0.128  0.854  0.941
# 90   1.000  0.212  0.274
# 91   1.000  0.142  0.358
# 92   0.064  0.312  0.356
# 93   0.064  0.377  0.284
# 94   0.487  0.238  0.485
# 95   0.487  0.262  0.556

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_3978/3088260556.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0).round(3)
# ADWIN           0.148
# HDDM            0.351
# NEWMA           0.525
# ChangeFinder    0.273
# DDM             0.511
# Window          0.525
# FLOSS           0.359
# ClaSS           0.455
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_3978/803467923.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.median(axis=0).round(3)
# ADWIN           0.096
# HDDM            0.340
# NEWMA           0.443
# ChangeFinder    0.254
# DDM             0.353
# Window          0.443
# FLOSS           0.362
# ClaSS           0.434
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_3978/2527189798.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0).round(3)
# ADWIN           0.125
# HDDM            0.198
# NEWMA           0.413
# ChangeFinder    0.180
# DDM             0.394
# Window          0.413
# FLOSS           0.197
# ClaSS           0.205
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method='min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 5)}")
# Out:
# ADWIN:wins=1 rank=6.52083
# HDDM:wins=5 rank=4.20833
# NEWMA:wins=39 rank=3.38542
# ChangeFinder:wins=6 rank=5.08333
# DDM:wins=32 rank=3.44792
# Window:wins=39 rank=3.38542
# FLOSS:wins=15 rank=3.91667
# ClaSS:wins=30 rank=3.26042

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4,
                                      filename=f"../../figures/cd_comparative_{dataset}.pdf")  #

# %% [markdown]
# Let's compute wins/losses against ClaSS.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue

    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method='min', ascending=False)

    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]

    assert wins + losses + ties == pair_ranks.shape[0]

    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs ADWIN: (wins/ties/losses): 89/0/7
# ClaSS vs HDDM: (wins/ties/losses): 67/0/29
# ClaSS vs NEWMA: (wins/ties/losses): 48/3/45
# ClaSS vs ChangeFinder: (wins/ties/losses): 75/0/21
# ClaSS vs DDM: (wins/ties/losses): 49/3/44
# ClaSS vs Window: (wins/ties/losses): 48/3/45
# ClaSS vs FLOSS: (wins/ties/losses): 69/1/26

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10, 5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0 + .2, .2), 1))

plt.savefig(f"../../figures/bp_comparative_{dataset}.pdf", bbox_inches="tight")
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_3978/3898032719.py:8: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_3978/3898032719.py:11: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(fontsize)
