# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare ClaSS with competitors.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../../")

from tqdm import tqdm

# %%
from src.visualizer import plot_profile, plot_profile_with_ts

# %% [markdown]
# Let's choose a score for evaluation (F1 or Covering).

# %%
eval_score = "covering_score"

# %% [markdown]
# Let's load the scores from the different methods.

# %%
competitors = ["ClaSS", "FLOSS", "Window"] # "BOCD", 
dataset = "MIT-BIH-Arr"
methods = list()

for candidate_name in competitors:
    methods.append((candidate_name, f"{candidate_name}.csv.gz"))

for idx, (name, file_name) in enumerate(methods):
    methods[idx] = name, pd.read_csv(f"../../experiments/competitor_{dataset}/{file_name}", compression="gzip")
    
df_scores = pd.DataFrame()

for name, df in methods:
    df_scores["dataset"] = df.dataset
    df_scores[name] = df[eval_score]
    
df_scores
# Out:
#                         dataset  ClaSS  FLOSS  Window
# 0   MIT-BIH-Arr_MLII_Subject100  0.660  0.500   1.000
# 1     MIT-BIH-Arr_V5_Subject100  0.742  0.531   1.000
# 2   MIT-BIH-Arr_MLII_Subject101  0.516  0.234   1.000
# 3     MIT-BIH-Arr_V1_Subject101  0.132  0.140   1.000
# 4     MIT-BIH-Arr_V5_Subject102  0.987  0.870   0.819
# 5     MIT-BIH-Arr_V2_Subject102  0.581  0.867   0.819
# 6   MIT-BIH-Arr_MLII_Subject103  0.329  0.291   1.000
# 7     MIT-BIH-Arr_V2_Subject103  0.396  0.175   1.000
# 8     MIT-BIH-Arr_V5_Subject104  0.543  0.436   0.242
# 9     MIT-BIH-Arr_V2_Subject104  0.509  0.469   0.242
# 10  MIT-BIH-Arr_MLII_Subject105  0.306  0.123   1.000
# 11    MIT-BIH-Arr_V1_Subject105  0.275  0.070   1.000
# 12  MIT-BIH-Arr_MLII_Subject106  0.372  0.306   0.126
# 13    MIT-BIH-Arr_V1_Subject106  0.380  0.375   0.126
# 14  MIT-BIH-Arr_MLII_Subject107  0.442  0.148   1.000
# 15    MIT-BIH-Arr_V1_Subject107  0.256  0.144   1.000
# 16  MIT-BIH-Arr_MLII_Subject108  0.186  0.098   1.000
# 17    MIT-BIH-Arr_V1_Subject108  0.219  0.047   1.000
# 18  MIT-BIH-Arr_MLII_Subject109  0.251  0.536   1.000
# 19    MIT-BIH-Arr_V1_Subject109  0.182  0.336   1.000
# 20  MIT-BIH-Arr_MLII_Subject111  0.276  0.083   1.000
# 21    MIT-BIH-Arr_V1_Subject111  0.289  0.093   1.000
# 22  MIT-BIH-Arr_MLII_Subject112  0.389  0.228   1.000
# 23    MIT-BIH-Arr_V1_Subject112  0.272  0.291   1.000
# 24  MIT-BIH-Arr_MLII_Subject113  0.540  0.390   1.000
# 25    MIT-BIH-Arr_V1_Subject113  0.184  0.331   1.000
# 26    MIT-BIH-Arr_V5_Subject114  0.314  0.108   0.522
# 27  MIT-BIH-Arr_MLII_Subject114  0.504  0.326   0.522
# 28  MIT-BIH-Arr_MLII_Subject115  0.575  0.189   1.000
# 29    MIT-BIH-Arr_V1_Subject115  0.713  0.288   1.000
# 30  MIT-BIH-Arr_MLII_Subject116  0.283  0.136   1.000
# 31    MIT-BIH-Arr_V1_Subject116  0.416  0.134   1.000
# 32  MIT-BIH-Arr_MLII_Subject117  0.576  0.440   1.000
# 33    MIT-BIH-Arr_V2_Subject117  0.598  0.586   1.000
# 34  MIT-BIH-Arr_MLII_Subject118  0.197  0.126   1.000
# 35    MIT-BIH-Arr_V1_Subject118  0.197  0.127   1.000
# 36  MIT-BIH-Arr_MLII_Subject119  0.374  0.415   0.029
# 37    MIT-BIH-Arr_V1_Subject119  0.185  0.252   0.029
# 38  MIT-BIH-Arr_MLII_Subject121  0.405  0.121   1.000
# 39    MIT-BIH-Arr_V1_Subject121  0.329  0.055   1.000
# 40  MIT-BIH-Arr_MLII_Subject122  0.377  0.048   1.000
# 41    MIT-BIH-Arr_V1_Subject122  0.581  0.197   1.000
# 42  MIT-BIH-Arr_MLII_Subject123  0.999  0.135   1.000
# 43    MIT-BIH-Arr_V5_Subject123  0.640  0.121   1.000
# 44  MIT-BIH-Arr_MLII_Subject124  0.594  0.413   0.184
# 45    MIT-BIH-Arr_V4_Subject124  0.777  0.648   0.184
# 46  MIT-BIH-Arr_MLII_Subject200  0.256  0.444   0.022
# 47    MIT-BIH-Arr_V1_Subject200  0.243  0.316   0.022
# 48  MIT-BIH-Arr_MLII_Subject201  0.446  0.461   0.090
# 49    MIT-BIH-Arr_V1_Subject201  0.439  0.444   0.090
# 50  MIT-BIH-Arr_MLII_Subject202  0.727  0.480   0.437
# 51    MIT-BIH-Arr_V1_Subject202  0.574  0.533   0.437
# 52  MIT-BIH-Arr_MLII_Subject203  0.442  0.355   0.091
# 53    MIT-BIH-Arr_V1_Subject203  0.136  0.385   0.091
# 54  MIT-BIH-Arr_MLII_Subject205  0.860  0.441   0.265
# 55    MIT-BIH-Arr_V1_Subject205  0.856  0.499   0.265
# 56  MIT-BIH-Arr_MLII_Subject207  0.279  0.297   0.493
# 57    MIT-BIH-Arr_V1_Subject207  0.431  0.281   0.493
# 58  MIT-BIH-Arr_MLII_Subject208  0.315  0.307   0.104
# 59    MIT-BIH-Arr_V1_Subject208  0.259  0.368   0.104
# 60  MIT-BIH-Arr_MLII_Subject209  0.625  0.556   0.211
# 61    MIT-BIH-Arr_V1_Subject209  0.536  0.328   0.211
# 62  MIT-BIH-Arr_MLII_Subject210  0.605  0.601   0.214
# 63    MIT-BIH-Arr_V1_Subject210  0.487  0.443   0.214
# 64  MIT-BIH-Arr_MLII_Subject212  0.101  0.084   1.000
# 65    MIT-BIH-Arr_V1_Subject212  0.100  0.069   1.000
# 66  MIT-BIH-Arr_MLII_Subject213  0.241  0.540   0.091
# 67    MIT-BIH-Arr_V1_Subject213  0.477  0.535   0.091
# 68  MIT-BIH-Arr_MLII_Subject214  0.431  0.479   0.106
# 69    MIT-BIH-Arr_V1_Subject214  0.484  0.464   0.106
# 70  MIT-BIH-Arr_MLII_Subject215  0.417  0.674   0.449
# 71    MIT-BIH-Arr_V1_Subject215  0.434  0.202   0.449
# 72  MIT-BIH-Arr_MLII_Subject217  0.551  0.451   0.077
# 73    MIT-BIH-Arr_V1_Subject217  0.519  0.460   0.077
# 74  MIT-BIH-Arr_MLII_Subject219  0.607  0.582   0.159
# 75    MIT-BIH-Arr_V1_Subject219  0.572  0.502   0.159
# 76  MIT-BIH-Arr_MLII_Subject220  0.580  0.379   0.269
# 77    MIT-BIH-Arr_V1_Subject220  0.269  0.403   0.269
# 78  MIT-BIH-Arr_MLII_Subject221  0.238  0.238   0.238
# 79    MIT-BIH-Arr_V1_Subject221  0.238  0.555   0.238
# 80  MIT-BIH-Arr_MLII_Subject222  0.422  0.482   0.103
# 81    MIT-BIH-Arr_V1_Subject222  0.521  0.354   0.103
# 82  MIT-BIH-Arr_MLII_Subject223  0.714  0.514   0.104
# 83    MIT-BIH-Arr_V1_Subject223  0.736  0.617   0.104
# 84  MIT-BIH-Arr_MLII_Subject228  0.624  0.642   0.070
# 85    MIT-BIH-Arr_V1_Subject228  0.600  0.609   0.070
# 86  MIT-BIH-Arr_MLII_Subject230  0.579  0.457   0.027
# 87    MIT-BIH-Arr_V1_Subject230  0.593  0.440   0.027
# 88  MIT-BIH-Arr_MLII_Subject231  0.945  0.815   0.128
# 89    MIT-BIH-Arr_V1_Subject231  0.939  0.854   0.128
# 90  MIT-BIH-Arr_MLII_Subject232  0.274  0.212   1.000
# 91    MIT-BIH-Arr_V1_Subject232  0.358  0.142   1.000
# 92  MIT-BIH-Arr_MLII_Subject233  0.356  0.312   0.064
# 93    MIT-BIH-Arr_V1_Subject233  0.284  0.377   0.064
# 94  MIT-BIH-Arr_MLII_Subject234  0.485  0.238   0.487
# 95    MIT-BIH-Arr_V1_Subject234  0.556  0.262   0.487

# %% [markdown]
# Let's calculate the mean/median/std score.

# %%
df_scores.mean(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_1244/2219294936.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0).round(3)
# ClaSS     0.454
# FLOSS     0.359
# Window    0.525
# dtype: float64

# %%
df_scores.median(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_1244/1729043111.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.median(axis=0).round(3)
# ClaSS     0.436
# FLOSS     0.362
# Window    0.443
# dtype: float64

# %%
df_scores.std(axis=0).round(3)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_1244/1084607075.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0).round(3)
# ClaSS     0.206
# FLOSS     0.197
# Window    0.413
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 5)}")
# Out:
# ClaSS:wins=33 rank=1.73958
# FLOSS:wins=20 rank=2.19792
# Window:wins=45 rank=2.01042

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], cd=cd, reverse=True, width=4, filename=f"../../figures/cd_comparative_{dataset}.pdf") #

# %% [markdown]
# Let's compute wins/losses against ClaSP.

# %%
selection = "ClaSS"

for rival in df_scores.columns[1:]:
    if rival == selection: continue
    
    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=False)
    
    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# ClaSS vs FLOSS: (wins/ties/losses): 70/1/25
# ClaSS vs Window: (wins/ties/losses): 47/3/46

# %%
fontsize = 24
_, ax = plt.subplots(figsize=(10,5))

df_scores.boxplot(ax=ax, rot=90)
ax.set_ylabel("Covering", fontsize=fontsize)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize)
    
ax.set_xticklabels(df_scores.columns[1:], rotation=45, ha="right")
ax.set_yticks(np.round(np.arange(0, 1.0+.2,.2),1))
    
plt.savefig(f"../../figures/bp_comparative_{dataset}.pdf", bbox_inches="tight")
