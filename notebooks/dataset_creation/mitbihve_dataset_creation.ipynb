# %% [markdown]
# # MIT-BIHMV Dataset Creation
# In this notebook, we create TS from the BIHMV data archive.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
import wfdb
import os
sys.path.append("../../")

from scipy import signal
from tqdm import tqdm
from src.visualizer import plot_ts

# %% [markdown]
# First, we need to download the PhysioNet record and annotation from https://physionet.org/content/vfdb/1.0.0/.

# %%
subject = 418

# %%
rec = wfdb.rdrecord(f"{subject}", pn_dir='vfdb')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_2510/2387258623.py in <module>
# ----> 1 rec = wfdb.rdrecord(f"{subject}", pn_dir='vfdb')
#
# ~/miniconda3/envs/py3k/lib/python3.8/site-packages/wfdb/io/record.py in rdrecord(record_name, sampfrom, sampto, channels, physical, pn_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    3431         record = wav2mit(record_name, pn_dir=pn_dir, record_only=True)
#    3432     else:
# -> 3433         record = rdheader(record_name, pn_dir=pn_dir, rd_segments=False)
#    3434
#    3435     # Set defaults for sampto and channels input variables
#
# ~/miniconda3/envs/py3k/lib/python3.8/site-packages/wfdb/io/record.py in rdheader(record_name, pn_dir, rd_segments)
#    3257
# ...

# %%
ann = wfdb.rdann(f"{subject}", "atr", pn_dir='vfdb')

# %%
signal = 1
name = f"MIT-BIH-VE_{rec.sig_name[signal]}{signal}_Subject{subject}"
ts = rec.p_signal[:,signal]
cps = np.array(ann.sample)[np.array(ann.symbol) == "+"]

# ignore first CPs as it marks the beginning 
cps = cps[1:]

# %%
np.unique(ann.symbol)
# Out:
# array(['+'], dtype='<U1')

# %% [markdown]
# Let's visualise the TS.

# %%
plot_ts(
    name,
    ts,
    cps,
    show=True
)

# %% [markdown]
# Finally, let's save the TS dataset.

# %%
DATASET_PATH = "../../datasets/MIT-BIH-VE/"

# %%
if not os.path.exists(DATASET_PATH):
    os.mkdir(DATASET_PATH)

# %%
records = pd.read_csv("https://physionet.org/files/vfdb/1.0.0/RECORDS", header=None)[0].to_numpy()

desc = []
data = dict()
signal = 1
window_size = 250

for subject in tqdm(records):
    rec = wfdb.rdrecord(f"{subject}", pn_dir='vfdb')
    ann = wfdb.rdann(f"{subject}", "atr", pn_dir='vfdb')
    
    for signal in range(len(rec.sig_name)):
        name = f"MIT-BIH-VE_{rec.sig_name[signal]}_Subject{subject}"
        ts = rec.p_signal[:,signal]
        cps = np.array(ann.sample)[np.array(ann.symbol) == "+"]

        # ignore first CPs as it marks the beginning 
        cps = cps[1:]

        desc.append(f"{name},{window_size},{','.join(dp.map(str, cps))}")
        data[name] = ts
            
np.savetxt(f"{DATASET_PATH}desc.txt", desc, fmt="%s")
np.savez(f"{DATASET_PATH}data.npz", **data)
# Out:
# 100%|███████████████████████████████████████████| 22/22 [01:41<00:00,  4.59s/it]
